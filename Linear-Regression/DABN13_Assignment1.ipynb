# %% [markdown]
# # DABN13 - Assignment 1
#
# This assignment comes in the form of a Jupyter notebook which you are supposed to fill in. All instances that require you input are marked by "??". Please replace that with the corresponding code for a given task. Additionally, you need to uncomment all commented ('#') lines in the code chunks below in order to make the script work. Moreover, note the following:
#
# * Often, we have specified names for objects that you are supposed to create. Use them. Do not come up with any object names of your own.
# * Tasks that require you to write a function will provide you with function name, all inputs to the function as well as the function output. Your task is to write operations within the function that work with these given parameters.
# * At times, you will be asked to use a specific function to complete a task. If this is the case, please follow instructions to the point. Do not implement any alternative  way of performing the task.
# * Sometimes, you might have questions concerning the use of a specific function in python. Please approach this situation as in a real-life programming situation: First, use the documentation of the relevant python package to find an answer. If unsuccessful, use Google. If still unsuccessful, post your question in the discussion section of our course page on Canvas.
# * Please write text answers into the corresponding string variables.
#
# Before we start, we will need to load the libraries that we use. We will work with os, NumPy, Pandas and statsmodels. Please import them using the following code block.

# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np

# %% [markdown]
# ## Part one: Linear regression practice
#
# In this basic section, we are goign to use the standard canned routines for linear regression in R.
#
# ### Load the data set
#
# We will be working with `Guns.dta`, a Stata dataset containing yearly US state data between 1977 and 1999 of three different crime rates, a number of additional state characteristics, as well as an indicator for the existence of a "shall-carry" law that allows citizens to obtain a permission to wear concealed handguns. In the following, you will fit a simple predictive model for state-wide violent crime rates.
#
# To begin with, use the `read_stata()` command in Pandas to load `Guns.dta` into a pandas dataframe called `Guns`

# %%
# os.chdir("") # Change working directory here
Guns = pd.read_stata("Guns.dta")

Guns.head(100)
# Out:
#     year         vio   mur         rob  incarc_rate    pb1064     pw1064  \
# 0     77  414.399994  14.2   96.800003           83  8.384873  55.122906
# 1     78  419.100006  13.3   99.099998           94  8.352101  55.143665
# 2     79  413.299988  13.2  109.500000          144  8.329575  55.135857
# 3     80  448.500000  13.2  132.100006          141  8.408386  54.912586
# 4     81  470.500000  11.9  126.500000          149  8.483435  54.925125
# ..   ...         ...   ...         ...          ...       ...        ...
# 95    80  893.599976  14.5  384.200012           93  5.594304  64.438271
# 96    81  863.000000  13.0  388.200012           98  5.764122  64.164764
# 97    82  814.700012  11.2  372.100006          114  5.955957  63.594181
# 98    83  772.599976  10.5  340.899994          135  6.108492  63.024395
# 99    84  763.400024  10.6  327.500000          150  6.266548  62.473785
#
#        pm1029        pop     avginc   density  stateid  shall
# 0   18.174412   3.780403   9.563148  0.074552        1      0
# 1   17.994080   3.831838   9.932000  0.075567        1      0
# 2   17.839336   3.866248   9.877028  0.076245        1      0
# 3   17.734198   3.900368   9.541428  0.076829        1      0
# 4   17.673716   3.918531   9.548351  0.077187        1      0
# ..        ...        ...        ...       ...      ...    ...
# 95  18.383966  23.800800  14.543061  0.152277        6      0
# 96  18.330189  24.285936  14.472679  0.155381        6      0
# 97  18.204891  24.820007  14.214767  0.158798        6      0
# 98  18.008028  25.360023  14.491000  0.162253        6      0
# 99  17.793894  25.844389  15.273993  0.165352        6      0
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Task 1a)
# As a first task, we learn a linear regression using statsmodels. The statsmodels documentation on [linear regressions](https://www.statsmodels.org/stable/regression.html#module-reference) provides you with sufficient information to conduct this task.
#
# First you need to define a linear regression object using the `OLS()`-function in statsmodels. To begin with, this object only defines the model inputs and outputs. Accordingly, `OLS()` requires you to specify the model output and the inputs as separate function arguments. It is best to create separate pandas dataframes `y_1a` and `X_1a` for output and inputs before using them for model training.
#
# Now use `OLS()` to create a linear regression object with log violent crime rate as output and the following input variables:
#
# * the logarithm of state population,
# * average per capita income,
# * shall-carry law in effect,
# * log murder rates,
# * log robbery rates,
# * an intercept
#
# Save this regression object as `lm_spec1a`.
#
# Finally, learn the parameters of the regression model by applying the `fit()`-method to `lm_spec_1a` and save the resulting object as `lm_fit_1a`.

# %%
# 1.
y_1a = Guns.assign(vio=np.log(Guns['vio']))['vio']
X_1a = Guns.assign(intercept=1, pop=np.log(Guns['pop']), mur=np.log(Guns['mur']), rob=np.log(Guns['rob']))[['intercept','avginc', 'shall', 'pop', 'mur', 'rob']]


# 2.
lm_spec_1a = sm.OLS(y_1a, X_1a)

# 3.
lm_fit_1a  = lm_spec_1a.fit()

print(lm_fit_1a.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    vio   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     1375.
# Date:                Mon, 16 Sep 2024   Prob (F-statistic):               0.00
# Time:                        12:02:03   Log-Likelihood:                -18.845
# No. Observations:                1173   AIC:                             49.69
# Df Residuals:                    1167   BIC:                             80.09
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      3.1392      0.050     63.255      0.000       3.042       3.237
# avginc         0.0190      0.003      5.515      0.000       0.012       0.026
# shall          0.0317      0.018      1.741      0.082      -0.004       0.067
# pop           -0.0289      0.009     -3.181      0.002      -0.047      -0.011
# mur            0.2652      0.018     14.795      0.000       0.230       0.300
# rob            0.4650      0.017     27.126      0.000       0.431       0.499
# ==============================================================================
# Omnibus:                        7.440   Durbin-Watson:                   0.240
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                7.356
# Skew:                           0.188   Prob(JB):                       0.0253
# Kurtosis:                       3.093   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Task 1b)
# Least squares regression coefficients are saved inside ` lm_fit_1a ` as attribute `params`. Extract its content into a single 6x1 NumPy array `lm_coef_1b`.

# %%
lm_coef_1b = np.array(lm_fit_1a.params)
lm_coef_1b = lm_coef_1b.reshape((6,1))
print(lm_coef_1b)
# Out:
# [[ 3.13920382]
#  [ 0.0189599 ]
#  [ 0.03172033]
#  [-0.02893736]
#  [ 0.26524857]
#  [ 0.46498793]]

# %% [markdown]
# ### Task 1c)
# In order to obtain training data predictions, we can apply the `predict()`-method to `lm_fit_1a`. The only argument you need to specify is the training inputs. Do this and save your predicted outputs as `lm_pred_1c`.
#
# The data for which we predict here is the same data used for model training. Accordingly, only need to specify one argument (i.e. input) for `predict()`.

# %%
lm_pred_1c = lm_fit_1a.predict(X_1a)
print(lm_pred_1c)
# Out:
# 0       6.112033
# 1       6.112186
# 2       6.155287
# 3       6.235917
# 4       6.188272
#           ...
# 1168    4.997221
# 1169    5.177081
# 1170    5.141063
# 1171    5.191904
# 1172    4.983467
# Length: 1173, dtype: float64

# %% [markdown]
# ### Task 1d)
# Model residuals can be manually constructed by subtracting training predictions from training outputs. Obtain the model residuals of the regression from Task 1a in this way and save it as `lm_res_1d`.
#
# Additionally, residuals are saved inside the ` lm_fit_1a ` object. Use the `dir()`-function to report the names of all attributes within ` lm_fit_1a `. Save this vector of names as `lm_objnames`.
#
# Lastly, calculate the sum of *squared* differences between the residuals that you find inside ` lm_fit_1a ` and `lm_res_1d`.

# %%
# 1.
lm_res_1d = y_1a - lm_pred_1c

# 2.
lm_objnames = dir(lm_fit_1a) 

# 3.
diff_res = sum((lm_fit_1a.resid - lm_res_1d)**2)

print(diff_res)
# Out:
# 0.0

# %% [markdown]
# ## Task 1e)
# A good prediction model for violent crime rates should capture all systematic patterns in the variation of this variable. A simple, but very effective way of finding out whether this is the case is to look at residual plots. If model residuals look like more than completely random noise, then there must be patterns left that we can exploit. Conduct the following steps:
#
# 1. Create a pandas data frame `plotdata_1e` that contains training data predictions and residuals from `lm_fit1a`.
# 2. Complete the code chunk that applies the `scatter`-method on `ax_1e` by making appropriate replacements for `??`. We want a plot that has model residuals from on the y-axis and outcome predictions on the x-axis.
# 3.  Do you see any remaining systematic patterns in the data? Write your well-motivated answer into the string variable `rem_patterns1e`.

# %%
# 1.
plotdata_1e = pd.DataFrame({'Predictions': lm_pred_1c, 'Residuals': lm_fit_1a.resid})

#2
from matplotlib.pyplot import subplots
fig_1e, ax_1e = subplots(figsize=(8, 8))
ax_1e.scatter(x="Predictions", y="Residuals", marker='x', data=plotdata_1e, label='Scatter Plot')
ax_1e.set_xlabel("Predicted output value")
ax_1e.set_ylabel("Residuals")
ax_1e.legend()

# Fit Line
lowess = sm.nonparametric.lowess(lm_res_1d, lm_pred_1c)
lowess_x, lowess_y = zip(*lowess)
ax_1e.plot(lowess_x, lowess_y, color='red', label='Lowess Smoothed', linewidth=2)

# 3.
rem_patterns1e = """Upon visual inspection of the residuals vs. predictions plot, most residuals seem to be randomly scattered around zero. 
However, there's some spread in both positive and negative directions. There are some systematic patterns remaining, particularly at the extremes of the predicted values, which might suggest the need for a more complex model or further transformation of variables.
"""

print(rem_patterns1e)
# Out:
# Upon visual inspection of the residuals vs. predictions plot, most residuals seem to be randomly scattered around zero.
# However, there's some spread in both positive and negative directions. There are some systematic patterns remaining, particularly at the extremes of the predicted values, which might suggest the need for a more complex model or further transformation of variables.

# %% [markdown]
# ### Task 1f)
# Let us proceed with another plot that should highlight an obvious source of unaccounted patterns in the data. Conduct the following steps:
#
# 1. Create a pandas data frame `plotdata_1f` which adds the variable `stateid` from `Guns` to `plotdata_1e`.
# 2. Plot the model residuals (x-axis) against ` stateid` (y-axis).
# 3. Describe any patterns that you see or conclude that you don't see any. Irrespective of your choice, write your answer into the string variable `whatIsee_1f`

# %%
# 1.
plotdata_1f = pd.DataFrame({'Predictions': lm_pred_1c, 'Residuals': lm_fit_1a.resid, 'stateid': Guns['stateid'].astype(float)})

# 2.
fig_1f, ax_1f = subplots(figsize = (8,8))
ax_1f.scatter(x='Residuals', y='stateid', marker='x', data=plotdata_1f)
ax_1f.set_xlabel("Residuals")
ax_1f.set_ylabel("State ID")

# 3.
whatIsee1f = """Appears to be some clustering of residuals by state, indicating potential state-level effects that the model has not captured. This suggests that there are unaccounted for patterns related to the state variable, which could be due to specific state characteristics or policies influencing crime rates. To improve the model, it may be useful to include state-level fixed effects or additional state-specific covariates to account for these differences."""


print(whatIsee1f)
# Out:
# Appears to be some clustering of residuals by state, indicating potential state-level effects that the model has not captured. This suggests that there are unaccounted for patterns related to the state variable, which could be due to specific state characteristics or policies influencing crime rates. To improve the model, it may be useful to include state-level fixed effects or additional state-specific covariates to account for these differences.

# %% [markdown]
# ### Task 1g)
# `stateid` is a variable that want to add to our model specification in some form. Before doing this, use the `describe()` method on `Guns` to get some descriptive statistics and save them as object `summary_1g`. Use the `include` argument correctly to force python to provide information on variables of *any* data type.
#
# You will see that a mean and a median are reported. Hence, as what type of variable is `stateid` apparently seen by R? Write your answer into the string variable `typeofvarb_1g`.
#
# Would it make sense to add `stateid` variable into our model from Task 1a) as it currently is? Why or why not? Write your answer into the string variable `in_regmodel_1g`.

# %%
summary_1g = Guns.describe(include='all')
print(summary_1g)

typeofvarb_1g  = """stateid is treated as a numeric variable, because the mean value of stateid is 28.9608 that is a continous variable, the median is 29 that is 
a discrete variable."""

in_regmodel_1g = """Firstly, it does not make sense to include stateid as a continuous variable because it falsely implies a meaningful numerical 
relationship between the states. Secondly, including stateid as a categorical variable allows us to understand how crime rates differ across states without 
assuming an ordering between them. Each state gets its own effect in the model, enabling us to see state-specific influences on crime."""
# Out:
#               year          vio          mur          rob  incarc_rate  \
# count  1173.000000  1173.000000  1173.000000  1173.000000  1173.000000
# mean     88.000000   503.074707     7.665132   161.820206   226.579710
# std       6.636079   334.277039     7.522707   170.509842   178.888094
# min      77.000000    47.000000     0.200000     6.400000    19.000000
# 25%      82.000000   283.100006     3.700000    71.099998   114.000000
# 50%      88.000000   443.000000     6.400000   124.099998   187.000000
# 75%      94.000000   650.900024     9.800000   192.699997   291.000000
# max      99.000000  2921.800049    80.599998  1635.099976  1913.000000
#
#             pb1064       pw1064       pm1029          pop       avginc  \
# count  1173.000000  1173.000000  1173.000000  1173.000000  1173.000000
# mean      5.336217    62.945431    16.081129     4.816341    13.724796
# std       4.885689     9.761533     1.732143     5.252115     2.554542
# min       0.248207    21.780430    12.213680     0.402753     8.554884
# 25%       2.202196    59.939705    14.653370     1.187706    11.934755
# 50%       4.026213    65.061279    15.895169     3.271332    13.401551
# 75%       6.850673    69.200096    17.525715     5.685611    15.271010
# max      26.979570    76.525749    22.352686    33.145123    23.646713
#
#            density      stateid        shall
# count  1173.000000  1173.000000  1173.000000
# mean      0.352038    28.960784     0.242967
# std       1.355472    15.683522     0.429058
# min       0.000707     1.000000     0.000000
# 25%       0.031911    16.000000     0.000000
# 50%       0.081569    29.000000     0.000000
# 75%       0.177718    42.000000     0.000000
# max      11.102116    56.000000     1.000000

# %% [markdown]
# ### Task 1h)
# A tentative idea is to change `stateid` into a *category* variable. Perhaps `statmodels` reckognizes this and uses the individual categories as separate regressors. To see whether this actually happens, replace the variable `stateid` in `Guns` with a version if itself that is encoded as *category* variable. Use the `astype()` method for that.
#
# Next, get the summary statistics of this modified variable and save them as object `summary_1h`.
# What has changed? Write your answer into the string variable `whatchanged_1h`

# %%
Guns['stateid'] = Guns['stateid'].astype('category')
summary_1h      = Guns['stateid'].describe()
print(summary_1h)
whatchanged1h = """There is no descriptive statistics like mean or standar deviation in the summary there is still a count which is a int now and shows the number of unique 
categories, the most frequent category (top), and the frequency of the top category."""

print(whatchanged1h)
# Out:
# count     1173
# unique      51
# top          1
# freq        23
# Name: stateid, dtype: int64
# There is no descriptive statistics like mean or standar deviation in the summary there is still a count which is a int now and shows the number of unique
# categories, the most frequent category (top), and the frequency of the top category.

# %% [markdown]
# ### Task 1i)
# Create an input matrix `X_1i` that extends `X_1a` with the `stateid` variable as an additional column. Then, learn the regression model from Task 1a using our new input matrix `X_1i`. Use the `summary()` method to report a summary of the regression results.
# How has `statsmodels` included `stateid` into the model? Write your answer into the variable `howincluded_1i`

# %%
# 1.
X_1i       = X_1a.copy()
X_1i['stateid'] = Guns['stateid']

# 2.
lm_spec_1i = sm.OLS(y_1a, X_1i)
lm_fit_1i  = lm_spec_1i.fit()

print(lm_fit_1i.summary())

howincluded_1i = "stateID has been inculded as a numerical variable in the model with a Beta coefficient assigned to it"
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    vio   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     1162.
# Date:                Mon, 16 Sep 2024   Prob (F-statistic):               0.00
# Time:                        12:02:03   Log-Likelihood:                -11.321
# No. Observations:                1173   AIC:                             36.64
# Df Residuals:                    1166   BIC:                             72.11
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      3.2490      0.057     57.131      0.000       3.137       3.361
# avginc         0.0174      0.003      5.057      0.000       0.011       0.024
# shall          0.0387      0.018      2.129      0.034       0.003       0.074
# pop           -0.0244      0.009     -2.680      0.007      -0.042      -0.007
# mur            0.2589      0.018     14.465      0.000       0.224       0.294
# rob            0.4590      0.017     26.823      0.000       0.425       0.493
# stateid       -0.0019      0.000     -3.880      0.000      -0.003      -0.001
# ==============================================================================
# Omnibus:                       13.451   Durbin-Watson:                   0.238
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.874
# Skew:                           0.233   Prob(JB):                     0.000971
# Kurtosis:                       3.259   Cond. No.                         286.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Task 1j)
# The result of the previous task should have convinced you that we need to manually transform categorical input variables ourselves. Here, we are using the `get_dummies()` function in Pandas to achieve this goal. Use this function to transform `X_1i` into a dataset where the categorical variable `stateid` is replaced with indicator variables for its individual categories. Save this transformed input variable dataset as `X_1j`. Tell `get_dummies()` to drop the indicator variable for the first category in order to avoid the so-called *dummy-variable trap*.
#
# Next, learn a linear regression using `X_1j` as your input variables and `y_1a` as the output variable. How does the regression output differ from that in Task 1i? Write your answer into `howoutputdiffers_1j`.

# %%
# 1.
X_1j = pd.get_dummies(X_1i, columns=['stateid'], drop_first=True)


for col in X_1j.columns:
    if X_1j[col].dtype == 'bool':
        X_1j[col] = X_1j[col].astype(int)


# 2.
lm_spec_1j = sm.OLS(y_1a, X_1j)
lm_fit_1j  = lm_spec_1j.fit()
howoutputdiffers_1j = "Instead of including statedid as a numerical varaible it has been converted to a catagorical variable with each unique value in stateid given it own variable and the sateid varaible has been drop so now each uniq state has it own coefficeint."

print(lm_fit_1j.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    vio   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     557.8
# Date:                Mon, 16 Sep 2024   Prob (F-statistic):               0.00
# Time:                        12:02:03   Log-Likelihood:                 813.23
# No. Observations:                1173   AIC:                            -1514.
# Df Residuals:                    1117   BIC:                            -1231.
# Df Model:                          55
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      3.1276      0.111     28.056      0.000       2.909       3.346
# avginc         0.0429      0.003     14.753      0.000       0.037       0.049
# shall          0.0250      0.013      1.856      0.064      -0.001       0.052
# pop            0.0531      0.054      0.987      0.324      -0.052       0.159
# mur            0.0314      0.018      1.747      0.081      -0.004       0.067
# rob            0.5215      0.019     27.993      0.000       0.485       0.558
# stateid_2      0.0453      0.126      0.360      0.719      -0.202       0.292
# stateid_4     -0.0490      0.039     -1.245      0.213      -0.126       0.028
# stateid_5     -0.0217      0.047     -0.462      0.645      -0.114       0.071
# stateid_6     -0.3050      0.104     -2.919      0.004      -0.510      -0.100
# stateid_8     -0.1944      0.043     -4.530      0.000      -0.279      -0.110
# stateid_9     -0.7317      0.052    -14.061      0.000      -0.834      -0.630
# stateid_10    -0.1157      0.115     -1.005      0.315      -0.342       0.110
# stateid_11    -0.0506      0.125     -0.406      0.685      -0.295       0.194
# stateid_12    -0.0415      0.065     -0.638      0.523      -0.169       0.086
# stateid_13    -0.2494      0.043     -5.866      0.000      -0.333      -0.166
# stateid_15    -0.7661      0.090     -8.482      0.000      -0.943      -0.589
# stateid_16     0.2241      0.090      2.495      0.013       0.048       0.400
# stateid_17    -0.2930      0.064     -4.567      0.000      -0.419      -0.167
# stateid_18    -0.3616      0.040     -9.031      0.000      -0.440      -0.283
# stateid_19    -0.2604      0.053     -4.903      0.000      -0.365      -0.156
# stateid_20    -0.2410      0.050     -4.830      0.000      -0.339      -0.143
# stateid_21    -0.2837      0.038     -7.490      0.000      -0.358      -0.209
# stateid_22     0.0341      0.038      0.898      0.369      -0.040       0.109
# stateid_23    -0.3855      0.088     -4.395      0.000      -0.558      -0.213
# stateid_24    -0.2829      0.043     -6.532      0.000      -0.368      -0.198
# stateid_25    -0.2408      0.045     -5.315      0.000      -0.330      -0.152
# stateid_26    -0.2224      0.055     -4.012      0.000      -0.331      -0.114
# stateid_27    -0.6501      0.044    -14.755      0.000      -0.737      -0.564
# stateid_28    -0.1858      0.044     -4.220      0.000      -0.272      -0.099
# stateid_29    -0.2239      0.039     -5.781      0.000      -0.300      -0.148
# stateid_30    -0.1926      0.100     -1.932      0.054      -0.388       0.003
# stateid_31    -0.2377      0.070     -3.385      0.001      -0.375      -0.100
# stateid_32    -0.2653      0.088     -3.029      0.003      -0.437      -0.093
# stateid_33    -0.6705      0.098     -6.851      0.000      -0.863      -0.478
# stateid_34    -0.6148      0.050    -12.409      0.000      -0.712      -0.518
# stateid_35     0.3516      0.065      5.382      0.000       0.223       0.480
# stateid_36    -0.4549      0.084     -5.435      0.000      -0.619      -0.291
# stateid_37    -0.0626      0.043     -1.442      0.150      -0.148       0.023
# stateid_38    -0.5894      0.122     -4.847      0.000      -0.828      -0.351
# stateid_39    -0.4985      0.061     -8.182      0.000      -0.618      -0.379
# stateid_40    -0.0565      0.040     -1.409      0.159      -0.135       0.022
# stateid_41    -0.2183      0.049     -4.489      0.000      -0.314      -0.123
# stateid_42    -0.6550      0.063    -10.421      0.000      -0.778      -0.532
# stateid_44    -0.2855      0.094     -3.027      0.003      -0.470      -0.100
# stateid_45     0.3609      0.038      9.497      0.000       0.286       0.435
# stateid_46    -0.0952      0.113     -0.839      0.402      -0.318       0.127
# stateid_47    -0.2085      0.038     -5.485      0.000      -0.283      -0.134
# stateid_48    -0.2858      0.082     -3.506      0.000      -0.446      -0.126
# stateid_49    -0.2192      0.067     -3.268      0.001      -0.351      -0.088
# stateid_50    -0.2836      0.127     -2.242      0.025      -0.532      -0.035
# stateid_51    -0.6264      0.040    -15.509      0.000      -0.706      -0.547
# stateid_53    -0.3429      0.040     -8.515      0.000      -0.422      -0.264
# stateid_54    -0.4148      0.060     -6.904      0.000      -0.533      -0.297
# stateid_55    -0.7302      0.041    -17.820      0.000      -0.811      -0.650
# stateid_56     0.2850      0.128      2.219      0.027       0.033       0.537
# ==============================================================================
# Omnibus:                       44.434   Durbin-Watson:                   0.526
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.550
# Skew:                          -0.050   Prob(JB):                     2.45e-27
# Kurtosis:                       4.580   Cond. No.                     1.85e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.85e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Part two: Least squares regression mechanics
# In this more advanced section, you are supposed to create your own algorithms for some standard statistics of a fitted linear regression model from scratch. You are only allowed to use matrix and scalar operations like the NumPy functions
#
# `@, matmul(), transpose(), linalg.solve(), linalg.inv(), subtract(), sum(), mean()`
#
# (or their shortcuts) to manually produce results otherwise produced by `statmodels`.

# %% [markdown]
# ### Task 2a)
# Build a function that takes the two-dimensional NumPy arrays `X` and  `y` as its two arguments  and that returns the least squares
# estimate $\hat{\beta}$ of the slope coefficients on `X`.

# %%
def get_betas(x,y):
    x_t = np.transpose(x)
    beta_hat =((np.linalg.inv(x_t.dot(x))).dot(x_t)).dot(y)
    return beta_hat

# %% [markdown]
# ### Task 2b)
# Build a function that computes the model residuals as an object called `res`. Refer to the function written in Task 2a to get an estimate of the slope coefficients.

# %%
def get_residuals(x, y):
    beta_hat = get_betas(x, y)
    y_hat = np.matmul(x, beta_hat)
    res = y - y_hat
    return res

# %% [markdown]
# ### Task 2c)
# Build a function that computes $R^2$, i.e. the estimated proportion of variance of $y$ that is explained by the model inputs. Refer to the function written in Task 2b to get model residuals.

# %%
def calculate_R2(x, y):
    res = get_residuals(x, y)
    tss = np.sum((y - np.mean(y))**2)
    rss = np.sum(res**2)
    r_sq= 1 - (rss / tss)
    return r_sq

# %% [markdown]
# ### Task 2d)
# Next, prepare the inputs that we can feed into our functions. Transform the Pandas data frames `y_1a` and `X_1a` into two-dimensional NumPy arrays and save them as `y_2d` and `X_2d`, respectively.
#
# Then, use your function from Task 2a to learn the coefficient of a linear regression of `y_2d` on `X_2d` and save them as `lm_coef_2d`.

# %%
# 1.
y_2d = y_1a.to_numpy()
X_2d = X_1a.to_numpy()

# 2.
lm_coef_2d = get_betas(X_2d, y_2d)

print(lm_coef_2d)
# Out:
# [ 3.13920382  0.0189599   0.03172033 -0.02893736  0.26524857  0.46498793]

# %% [markdown]
# ### Task 2e)
# To what degree did the degree to which we picked up variation in the training data increase when we included state indicators? We are going to find that out by comparing $R^2$. First, transform the Pandas data frame `X_1j` into a Numpy array and save it as `X_2e`
#
# Then, use the function from Task 2c to obtain the training $R^2$ for a regression model with inputs `X_2d` and for a model with inputs `X_2e`. Save them as `R2_nostate_2e` and `R2_withstate_2e` respectively.
#
# Lastly, use the string variable `effect_of_stateid2e` to explain how much $R^2$ changed due to the use of state indicators as additional inputs.

# %%
# 1.
X_2e = X_1j.to_numpy()

# 2.
R2_nostate_2e = calculate_R2(X_2d,y_2d)

R2_withstate_2e = calculate_R2(X_2e,y_2d)

print((R2_withstate_2e, R2_nostate_2e))
# 3.
effect_of_stateid2e = "Including state indicators as additional inputs significantly increased the r-sqr value from 0.855 to 0.965. So with out the stateid about 85% change in the violent crime rate was explained by the input paramenter with the inclusion of stateID that change to about 96% which is a 11% increase. So with the inclusion of state variable our model perform better with the Guns traning data set."
# Out:
# (0.9648716660407913, 0.8548568792391293)
