# %% [markdown]
# # DABN13 - Assignment 4

# %% [markdown]
# ## Preamble: Predicting competitor airfares on new routes
#
# Air carriers regularly update their destination network and a necessary condition for adding a new flight connection to the existing network is that flights on this route are profitable. In addition to costs, profitability is determined by the price at which competitors could cater to the demand for flight transportation between two locations. A data-driven way of determining this would be on the basis of a supervised learning algorithm that has been trained on the fares for existing flight connections and which leverages information about route-specific characteristics. The dataset that we are using in this lab contains such information for more than 600 flight connections between different American cities. More specifically, we have information on the number of required stops, the market concentration on a particular route, Holiday destination status and a number of other characteristics that are detailed on [p.7 in the `mlba` library documentation](https://github.com/gedeck/mlba/blob/main/mlba_2.0.0.pdf). In the following, we will train and tune different supervised learning models that predict the average fare for a flight.
#
#
# Before conducting the first part of this assignment, let's load our data.

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import warnings

Airfares = pd.read_csv("Airfares.csv.gz") 
Airfares = Airfares.drop(columns=["S_CODE", "S_CITY", "E_CODE", "E_CITY"])

Airfares.head(20)
# Out:
#     COUPON  NEW VACATION   SW       HI  S_INCOME  E_INCOME    S_POP    E_POP  \
# 0     1.00    3       No  Yes  5291.99   28637.0   21112.0  3036732   205711
# 1     1.06    3       No   No  5419.16   26993.0   29838.0  3532657  7145897
# 2     1.06    3       No   No  9185.28   30124.0   29838.0  5787293  7145897
# 3     1.06    3       No  Yes  2657.35   29260.0   29838.0  7830332  7145897
# 4     1.06    3       No  Yes  2657.35   29260.0   29838.0  7830332  7145897
# 5     1.01    3       No  Yes  3408.11   26046.0   29838.0  2230955  7145897
# 6     1.28    3       No   No  6754.48   28637.0   29838.0  3036732  7145897
# 7     1.15    3      Yes  Yes  5584.00   26752.0   29838.0  1440377  7145897
# 8     1.33    3       No  Yes  4662.44   27211.0   29838.0  3770125  7145897
# 9     1.60    2       No  Yes  2617.00   25450.0   29838.0  1694803  7145897
# 10    1.57    3      Yes  Yes  1772.59   24575.0   29838.0  1197234  7145897
# 11    1.50    1       No  Yes  3932.29   24706.0   29838.0  9056076  7145897
# 12    1.12    3       No  Yes  4471.62   25995.0   29838.0  1115048  7145897
# 13    1.29    3       No  Yes  4356.12   22038.0   29838.0  1308499  7145897
# 14    1.00    3       No   No  2626.90   32991.0   29838.0  8621121  7145897
# 15    1.00    3       No   No  2626.90   32991.0   29838.0  8621121  7145897
# 16    1.00    3       No   No  2626.90   32991.0   29838.0  8621121  7145897
# 17    1.13    3      Yes  Yes  5706.76   22360.0   29838.0  1421287  7145897
# 18    1.86    3       No  Yes  1230.48   23025.0   29838.0  2753373  7145897
# 19    1.93    3       No  Yes  2000.67   21121.0   29838.0  1228816  7145897
#
#           SLOT         GATE  DISTANCE    PAX    FARE
# 0         Free         Free       312   7864   64.11
# 1         Free         Free       576   8820  174.47
# 2         Free         Free       364   6452  207.76
# 3   Controlled         Free       612  25144   85.47
# 4         Free         Free       612  25144   85.47
# 5         Free         Free       309  13386   56.76
# 6         Free         Free      1220   4625  228.00
# 7         Free         Free       921   5512  116.54
# 8         Free         Free      1249   7811  172.63
# 9         Free         Free       964   4657  114.76
# 10        Free         Free      2104   4489  158.20
# 11        Free         Free      2329   7349  228.99
# 12        Free         Free       587   5654   79.17
# 13        Free         Free       992   3525  132.05
# 14  Controlled         Free       181   7171  117.23
# 15  Controlled         Free       181   7171  117.23
# 16        Free  Constrained       181   7171  117.23
# 17        Free         Free       788  11013  106.11
# 18        Free         Free      2001   4408  181.16
# 19        Free         Free      1866   2767  157.50

# %% [markdown]
# ## Part one: Ridge regression with scikit-learn
# Ridge regression is supported in the `linear_models` module of scikit-learn. However, instead of using the `Ridge()`-function in this module, we are going to work with `ElasticNet()` because this function leads to ridge regression and the lasso as special cases.
#
# ### Task 1a)
# `sklearn` requires us to provide output and inputs separately as data frames containing numerical variables that can be directly put into a cost minimization problem. Provide that by conducting the following steps:
#
# 1. Save *all* predictors in `Airfares` as a Pandas dataframe `X_1a`. Then, use the `get_dummies()` function in Pandas to turn categorical variables into category dummies. Ensure that the first category of every categorical variable is dropped.
# 2. Save the output variable *FARE* as pandas series `y_1a`.
# 3. Use the  `train_test_split()` function in the model selection module of `sklearn` to split `X_1a` (`y_1a`) into training data `X_train_1a` (`y_train_1a`) and test data `X_test_1a` (`y_test_1a`).

# %%
# 1.
X_1a = Airfares.drop('FARE', axis=1)
X_1a = pd.get_dummies(X_1a, drop_first=True)

# 2. 
y_1a = Airfares['FARE']


# 3.
from sklearn.model_selection import train_test_split

X_train_1a, X_test_1a, y_train_1a, y_test_1a = train_test_split(X_1a, y_1a, test_size=0.3, random_state=42)

# %% [markdown]
# ### Task 1b)
# With a little effort, we can use `sklearn` to plot the relation between learned model coefficients and the regularization parameter.
# Unlike other estimator functions in `sklearn`, the coefficient path cannot be obtained by simply fitting a specified pipeline. We need to conduct all steps in that potential pipeline manually.
#
# 1. First, we manually do more data transformations. We want to expand the set of input variables by adding interactions of all original inputs to the data set. The function `PolynomialFeatures()` does that for us. Use this function to specify a transformation `poly2_spec_1b` which adds interactions between any two input variables to the data. Do not add squared terms and no constant neither.
# 2. We can even use the `Pipeline()` function without an estimator, e.g. do specify a sequence of transformations. Create such a pipeline `X_transform_pipe_1b`. It should contain `poly2_spec_1b` as its first step and standardization of all variables in the dataset (via `StandardScalar()` as its second step).
# 3. Use the `fit_transform()`-method on `X_transform_pipe_1b` to transform `X_train_1a` and save the result as `X_train_transformed_1b`.
# 4. Use the `enet_path()` function to learn the sequence of ridge regression parameters for the sequence of regularization parameter values `lambdas_1b` that I defined below. You will need to specify your model inputs and output, as well as the choice of `l1_ratio` which results in ridge regression. Save the result as `ridgepath_1b`. Then, run the provided code for plotting the coefficient path.

# %%
from sklearn.preprocessing import (StandardScaler, PolynomialFeatures)
from sklearn.pipeline import Pipeline
from sklearn.linear_model import enet_path

# 1.
poly2_spec_1b = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)

# 2.
X_transform_pipe_1b = Pipeline([('poly_features', poly2_spec_1b),('scaler', StandardScaler())])


# 3.
X_train_transformed_1b = X_transform_pipe_1b.fit_transform(X_train_1a)


# 4.
lambdas_1b = (np.logspace(7, 0, 100)/(y_train_1a.std(ddof=1)*2 * y_train_1a.shape[0]))

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning)
    ridgepath_1b    = enet_path(X_train_transformed_1b, y_train_1a, l1_ratio=0.0, alphas=lambdas_1b)


# Run the lines below for a plot of the coefficient path
ax = plt.gca()
for i in range(ridgepath_1b[1].shape[0]):
    plt.plot(ridgepath_1b[0]*y_train_1a.shape[0]*2, ridgepath_1b[1][i])

ax.set_xscale("log")
plt.xlabel("lambda")
plt.ylabel("learned coefficients")
plt.title("Ridge coefficient path")
plt.axis("tight") 
plt.grid(True)   

plt.show()

# %% [markdown]
# ### Task 1c)
# Now that we have inspected the coefficient path for ridge regression, we want to find an optimal tuning parameter value via K-fold cross-validation. This works almost exactly as in Assignment 3.
#
# 1. Specify a pipeline that contains the two transformations that we already specified in `X_transform_pipe_1b` as well as a ridge regression specification (use `Ridge()`). Save the specified pipeline as `ridge_pipe_1c`.
#
# 2. Put the set of tuning parameter candidates `lambdas_1c` below into a dictionary object `tune_grid_1c` that `GridSearchCV()` can handle when estimation function is the pipeline `ridge_pipe_1c`.
#
# 3. Use the `KFold()`-function to specify a **random** partition into five folds. Set the `random_state` to 5 for the sake of replicability.
#
# 4. Do 5-fold cross-validation to determine the optimal regularization parameter value among the candidates in `lambdas_1b` by calling the `GridSearchCV()`-function. Use the pipeline and the split specified in the previous two steps. Measure prediction performance with (negative) mean squared error. Save the resulting object as `ridge_tune_1c`.
# 5. Save the `cv_results_` object in `ridge_tune_1c` as `ridge_cv_out_1c`.

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import (KFold, GridSearchCV)

# 1.
ridge_pipe_1c  = Pipeline(steps = [('transformations', X_transform_pipe_1b),('ridge', Ridge())])

# 2.
lambdas_1c = np.logspace(7, 0, 100)/(y_train_1a.std(ddof=1))
tune_grid_1c = {'ridge__alpha': lambdas_1c}

# 3.
cv_splits_1c = KFold(n_splits=5, shuffle=True, random_state=5)

# 4.
ridge_tune_1c   = GridSearchCV(ridge_pipe_1c, param_grid=tune_grid_1c, cv=cv_splits_1c, scoring='neg_mean_squared_error')
ridge_tune_1c.fit(X_train_1a, y_train_1a)

# 5.
ridge_cv_out_1c = ridge_tune_1c.cv_results_

ridge_cv_out_1c
# Out:
# {'mean_fit_time': array([0.00703707, 0.00342798, 0.00400729, 0.00356898, 0.00289569,
#         0.0031208 , 0.00499563, 0.02368417, 0.00366402, 0.00277367,
#         0.00362821, 0.00296507, 0.00370545, 0.00428925, 0.00795455,
#         0.00338984, 0.00366139, 0.00489831, 0.00334764, 0.00323887,
#         0.00436873, 0.00346508, 0.00303602, 0.0484036 , 0.01279325,
#         0.0075964 , 0.00781202, 0.00452099, 0.00498462, 0.00491524,
#         0.00524449, 0.00592322, 0.00540395, 0.00399189, 0.02111902,
#         0.00999417, 0.00480776, 0.00549169, 0.01212349, 0.02827163,
#         0.00517612, 0.01120524, 0.00674434, 0.00821862, 0.01233239,
#         0.00330281, 0.00416737, 0.00314813, 0.00409708, 0.00432887,
#         0.00613089, 0.00607119, 0.00426669, 0.0059267 , 0.00465674,
#         0.00260239, 0.00762296, 0.00498562, 0.00357299, 0.00782428,
#         0.02265368, 0.00833902, 0.00518422, 0.00322838, 0.00388699,
#         0.0056664 , 0.00388198, 0.00577364, 0.00945778, 0.00456543,
#         0.00481524, 0.0055654 , 0.00587163, 0.00532017, 0.005443  ,
#         0.00591631, 0.00511241, 0.00507689, 0.00424623, 0.0084353 ,
#         0.01476331, 0.00679693, 0.00345645, 0.00497327, 0.00453672,
#         0.0065073 , 0.00513086, 0.00797911, 0.00455976, 0.00430169,
#         0.00418696, 0.00303087, 0.00557623, 0.00594058, 0.00575185,
#         0.00653696, 0.00587125, 0.00846186, 0.00557098, 0.00530558]),
#  'std_fit_time': array([0.00264836, 0.00183108, 0.00193494, 0.00221789, 0.00206885,
#         0.00153549, 0.00502827, 0.02947362, 0.00115645, 0.00061482,
#         0.00164316, 0.0008881 , 0.00192708, 0.00188663, 0.00502986,
#         0.00130782, 0.00124531, 0.00167904, 0.00231699, 0.00165383,
#         0.00219791, 0.00182612, 0.00175065, 0.07701307, 0.00323584,
#         0.00130393, 0.00481294, 0.00151483, 0.00164225, 0.0014176 ,
#         0.00186668, 0.00091624, 0.00254653, 0.00094793, 0.01498926,
#         0.00794991, 0.00164085, 0.00209668, 0.01682432, 0.04959785,
#         0.003017  , 0.01175293, 0.00545775, 0.0055786 , 0.01001228,
#         0.00166337, 0.0012801 , 0.0017354 , 0.00203617, 0.00160023,
#         0.00191009, 0.00321495, 0.0029031 , 0.00325177, 0.00276523,
#         0.00084941, 0.00379602, 0.00215149, 0.00238709, 0.00525609,
#         0.01311363, 0.00704726, 0.00174377, 0.00115463, 0.00159906,
#         0.00204665, 0.00167228, 0.00173323, 0.00983903, 0.00212616,
#         0.00190762, 0.00097279, 0.00274631, 0.0025419 , 0.00194726,
#         0.00247854, 0.0022563 , 0.00258438, 0.002472  , 0.00774181,
#         0.01824978, 0.00315621, 0.00132099, 0.0019586 , 0.00176584,
#         0.00221129, 0.00323816, 0.00332218, 0.00201292, 0.00090993,
#         0.00213611, 0.0008999 , 0.00343669, 0.00307936, 0.0025953 ,
#         0.00340213, 0.00363801, 0.00297382, 0.00223581, 0.00125869]),
#  'mean_score_time': array([0.00159621, 0.00090299, 0.00099745, 0.00097775, 0.00090761,
#         0.00087123, 0.00066123, 0.00409689, 0.00121131, 0.00127916,
#         0.00089555, 0.00094304, 0.00100198, 0.00110831, 0.00201163,
#         0.00094066, 0.00097022, 0.001017  , 0.00098934, 0.00105295,
#         0.00091987, 0.00086627, 0.00087967, 0.00551634, 0.0027844 ,
#         0.00111332, 0.0010046 , 0.00128136, 0.00129437, 0.00118198,
#         0.0012918 , 0.00169001, 0.00139546, 0.00103097, 0.00301933,
#         0.0015131 , 0.00137229, 0.0020257 , 0.00165029, 0.00075116,
#         0.00116763, 0.0009728 , 0.00176787, 0.00172777, 0.00136476,
#         0.00064421, 0.00129104, 0.00193844, 0.00114732, 0.00167789,
#         0.00163755, 0.00154161, 0.00132523, 0.00074425, 0.00153189,
#         0.00060139, 0.00131907, 0.00109458, 0.00101819, 0.00087442,
#         0.00157385, 0.00183387, 0.00209384, 0.00104337, 0.00065928,
#         0.00224452, 0.0006474 , 0.00112991, 0.00186839, 0.00157828,
#         0.00233455, 0.0017796 , 0.00082798, 0.00072322, 0.00082054,
#         0.0021193 , 0.00160079, 0.00202389, 0.0013494 , 0.00221834,
#         0.00127926, 0.00070925, 0.00120277, 0.00097475, 0.00106359,
#         0.00136757, 0.00156512, 0.00258923, 0.00183249, 0.00133376,
#         0.00158005, 0.00103002, 0.001407  , 0.00162201, 0.00110583,
#         0.00153532, 0.00083647, 0.00176749, 0.00170536, 0.00134783]),
#  'std_score_time': array([9.25407297e-04, 5.52034640e-04, 7.69020694e-04, 7.15209053e-04,
#         6.29221573e-04, 5.31477815e-04, 1.41965530e-04, 4.13795007e-03,
#         6.62046600e-04, 7.65806673e-04, 5.20502595e-04, 6.71548980e-04,
#         4.54505826e-04, 6.63463374e-04, 9.16882478e-04, 6.13907843e-04,
#         6.15177403e-04, 8.19181405e-04, 5.46134331e-04, 7.03492238e-04,
#         6.46040240e-04, 5.62527275e-04, 5.60196496e-04, 5.29915038e-03,
#         1.20730753e-03, 2.00556405e-04, 3.02588199e-04, 5.64571704e-04,
#         6.49233150e-04, 5.59718001e-04, 7.44459841e-04, 4.93377225e-04,
#         4.24425493e-04, 2.49872471e-04, 1.27026679e-03, 9.44293142e-04,
#         8.14186209e-04, 1.17677766e-03, 9.55213228e-04, 1.06663218e-04,
#         6.50184813e-04, 3.36088191e-04, 5.05565571e-04, 1.12720853e-03,
#         7.73075769e-04, 4.63065106e-05, 7.84092340e-04, 7.81601568e-04,
#         9.67530717e-04, 8.77612832e-04, 7.26319458e-04, 1.23411006e-03,
#         8.91980421e-04, 1.58251657e-04, 1.22182433e-03, 8.55467657e-06,
#         7.29671679e-04, 5.57758933e-04, 8.16905593e-04, 1.63321885e-04,
#         7.32942849e-04, 9.03572135e-04, 1.09500188e-03, 7.69830391e-04,
#         5.99967268e-05, 7.55826988e-04, 3.09674806e-05, 5.84314226e-04,
#         8.52945652e-04, 1.30376496e-03, 1.15890340e-03, 8.66949679e-04,
#         1.57758704e-04, 1.16756049e-04, 1.86258148e-04, 1.59736588e-03,
#         9.14661107e-04, 1.20072621e-03, 6.79812062e-04, 1.50939553e-03,
#         6.26750933e-04, 6.16654618e-05, 6.37092639e-04, 4.23924984e-04,
#         7.38809006e-04, 7.50267107e-04, 1.10791048e-03, 1.14625889e-03,
#         1.38420034e-03, 6.92929389e-04, 1.07542351e-03, 5.39001343e-04,
#         8.23356719e-04, 9.55465166e-04, 5.08525880e-04, 1.02185827e-03,
#         2.74297383e-04, 7.88492547e-04, 5.78293676e-04, 8.27677429e-04]),
#  'param_ridge__alpha': masked_array(data=[133324.4646666354, 113292.92194115403,
#                     96271.04968362559, 81806.65524719261,
#                     69515.48637649581, 59071.02339728783,
#                     50195.805094485324, 42654.057847239514,
#                     36245.43221113783, 30799.680557408203,
#                     26172.13437854633, 22239.86111323248,
#                     18898.398395100336, 16058.978969406944,
#                     13646.172556438201, 11595.882016835603,
#                     9853.640586197309, 8373.164944330027,
#                     7115.125680874263, 6046.102494244734,
#                     5137.696368340285, 4365.775141652526,
#                     3709.8324270237804, 3152.4428515087607,
#                     2678.7991445752123, 2276.3187772119268,
#                     1934.3097021591977, 1643.6863155212036,
#                     1396.728094170165, 1186.8744970512296,
#                     1008.5506818616258, 857.0194071999221,
#                     728.2551859085229, 618.8373464440567, 525.859161409425,
#                     446.8506292116979, 379.71285751057974,
#                     322.6623053283044, 274.1834025909306,
#                     232.98828842076622, 197.98259861202018,
#                     168.2363934206864, 142.9594533541066,
#                     121.4802866832737, 103.22829100427892,
#                     87.71859496386345, 74.53917746362163,
#                     63.33992215951669, 53.82331648523541,
#                     45.73654811532714, 38.86478890760028,
#                     33.02548791009749, 28.06352182416475,
#                     23.847074093781202, 20.26413314755861,
#                     17.21951676784817, 14.6323435381655,
#                     12.433884196951777, 10.565735818049962,
#                     8.978270314290997, 7.6293160480853555,
#                     6.483037525493486, 5.508983412412762, 4.68127758306148,
#                     3.977931710648604, 3.3802611389336006,
#                     2.8723885170772983, 2.4408220116509685,
#                     2.0740968908418584, 1.7624709594003045,
#                     1.4976657534396158, 1.2726466198280213,
#                     1.0814358378963826, 0.9189538189671943,
#                     0.7808841651087448, 0.6635590023478086,
#                     0.5638615421731622, 0.47914328283839136,
#                     0.407153650884471, 0.34598021378182764,
#                     0.29399787541751515, 0.24982570478587543,
#                     0.21229025102009616, 0.1803943702142352,
#                     0.15329073590812228, 0.1302593295308917,
#                     0.1106883128280315, 0.09405777414055057,
#                     0.07992591674985204, 0.06791732237633513,
#                     0.05771297804700581, 0.04904180139196331,
#                     0.04167343923597014, 0.03541214817689579,
#                     0.030091594586223208, 0.02557043589161312,
#                     0.02172856575658, 0.018463923409020755,
#                     0.015689782357169425, 0.013332446466663539],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'ridge__alpha': 133324.4646666354},
#   {'ridge__alpha': 113292.92194115403},
#   {'ridge__alpha': 96271.04968362559},
#   {'ridge__alpha': 81806.65524719261},
#   {'ridge__alpha': 69515.48637649581},
#   {'ridge__alpha': 59071.02339728783},
#   {'ridge__alpha': 50195.805094485324},
#   {'ridge__alpha': 42654.057847239514},
#   {'ridge__alpha': 36245.43221113783},
#   {'ridge__alpha': 30799.680557408203},
#   {'ridge__alpha': 26172.13437854633},
#   {'ridge__alpha': 22239.86111323248},
#   {'ridge__alpha': 18898.398395100336},
#   {'ridge__alpha': 16058.978969406944},
#   {'ridge__alpha': 13646.172556438201},
#   {'ridge__alpha': 11595.882016835603},
#   {'ridge__alpha': 9853.640586197309},
#   {'ridge__alpha': 8373.164944330027},
#   {'ridge__alpha': 7115.125680874263},
#   {'ridge__alpha': 6046.102494244734},
#   {'ridge__alpha': 5137.696368340285},
#   {'ridge__alpha': 4365.775141652526},
#   {'ridge__alpha': 3709.8324270237804},
#   {'ridge__alpha': 3152.4428515087607},
#   {'ridge__alpha': 2678.7991445752123},
#   {'ridge__alpha': 2276.3187772119268},
#   {'ridge__alpha': 1934.3097021591977},
#   {'ridge__alpha': 1643.6863155212036},
#   {'ridge__alpha': 1396.728094170165},
#   {'ridge__alpha': 1186.8744970512296},
#   {'ridge__alpha': 1008.5506818616258},
#   {'ridge__alpha': 857.0194071999221},
#   {'ridge__alpha': 728.2551859085229},
#   {'ridge__alpha': 618.8373464440567},
#   {'ridge__alpha': 525.859161409425},
#   {'ridge__alpha': 446.8506292116979},
#   {'ridge__alpha': 379.71285751057974},
#   {'ridge__alpha': 322.6623053283044},
#   {'ridge__alpha': 274.1834025909306},
#   {'ridge__alpha': 232.98828842076622},
#   {'ridge__alpha': 197.98259861202018},
#   {'ridge__alpha': 168.2363934206864},
#   {'ridge__alpha': 142.9594533541066},
#   {'ridge__alpha': 121.4802866832737},
#   {'ridge__alpha': 103.22829100427892},
#   {'ridge__alpha': 87.71859496386345},
#   {'ridge__alpha': 74.53917746362163},
#   {'ridge__alpha': 63.33992215951669},
#   {'ridge__alpha': 53.82331648523541},
#   {'ridge__alpha': 45.73654811532714},
#   {'ridge__alpha': 38.86478890760028},
#   {'ridge__alpha': 33.02548791009749},
#   {'ridge__alpha': 28.06352182416475},
#   {'ridge__alpha': 23.847074093781202},
#   {'ridge__alpha': 20.26413314755861},
#   {'ridge__alpha': 17.21951676784817},
#   {'ridge__alpha': 14.6323435381655},
#   {'ridge__alpha': 12.433884196951777},
#   {'ridge__alpha': 10.565735818049962},
#   {'ridge__alpha': 8.978270314290997},
#   {'ridge__alpha': 7.6293160480853555},
#   {'ridge__alpha': 6.483037525493486},
#   {'ridge__alpha': 5.508983412412762},
#   {'ridge__alpha': 4.68127758306148},
#   {'ridge__alpha': 3.977931710648604},
#   {'ridge__alpha': 3.3802611389336006},
#   {'ridge__alpha': 2.8723885170772983},
#   {'ridge__alpha': 2.4408220116509685},
#   {'ridge__alpha': 2.0740968908418584},
#   {'ridge__alpha': 1.7624709594003045},
#   {'ridge__alpha': 1.4976657534396158},
#   {'ridge__alpha': 1.2726466198280213},
#   {'ridge__alpha': 1.0814358378963826},
#   {'ridge__alpha': 0.9189538189671943},
#   {'ridge__alpha': 0.7808841651087448},
#   {'ridge__alpha': 0.6635590023478086},
#   {'ridge__alpha': 0.5638615421731622},
#   {'ridge__alpha': 0.47914328283839136},
#   {'ridge__alpha': 0.407153650884471},
#   {'ridge__alpha': 0.34598021378182764},
#   {'ridge__alpha': 0.29399787541751515},
#   {'ridge__alpha': 0.24982570478587543},
#   {'ridge__alpha': 0.21229025102009616},
#   {'ridge__alpha': 0.1803943702142352},
#   {'ridge__alpha': 0.15329073590812228},
#   {'ridge__alpha': 0.1302593295308917},
#   {'ridge__alpha': 0.1106883128280315},
#   {'ridge__alpha': 0.09405777414055057},
#   {'ridge__alpha': 0.07992591674985204},
#   {'ridge__alpha': 0.06791732237633513},
#   {'ridge__alpha': 0.05771297804700581},
#   {'ridge__alpha': 0.04904180139196331},
#   {'ridge__alpha': 0.04167343923597014},
#   {'ridge__alpha': 0.03541214817689579},
#   {'ridge__alpha': 0.030091594586223208},
#   {'ridge__alpha': 0.02557043589161312},
#   {'ridge__alpha': 0.02172856575658},
#   {'ridge__alpha': 0.018463923409020755},
#   {'ridge__alpha': 0.015689782357169425},
#   {'ridge__alpha': 0.013332446466663539}],
#  'split0_test_score': array([-5476.02724546, -5430.70059871, -5378.36684806, -5318.1351326 ,
#         -5249.06866649, -5170.20755191, -5080.60159029, -4979.35460774,
#         -4865.68117416, -4738.9754431 , -4598.89007772, -4445.42085799,
#         -4278.98975591, -4100.51642687, -3911.46586874, -3713.85932072,
#         -3510.23719298, -3303.56750378, -3097.10083368, -2894.18211953,
#         -2698.03872024, -2511.57063846, -2337.17044281, -2176.59633485,
#         -2030.91265742, -1900.50023064, -1785.12733269, -1684.06374731,
#         -1596.21670418, -1520.26875298, -1454.80228825, -1398.4015831 ,
#         -1349.7289435 , -1307.57580962, -1270.89199314, -1238.79708539,
#         -1210.57801483, -1185.67634641, -1163.66854266, -1144.24213928,
#         -1127.17055265, -1112.28891143, -1099.47281068, -1088.62123342,
#         -1079.64415219, -1072.45463159, -1066.96470834, -1063.08399848,
#         -1060.71988755, -1059.77827222, -1060.16407863, -1061.78111318,
#         -1064.53113233, -1068.31229586, -1073.01735497, -1078.53200927,
#         -1084.73384872, -1091.49219889, -1098.6690413 , -1106.12101998,
#         -1113.70239909, -1121.26872418, -1128.68086864, -1135.80911867,
#         -1142.5369626 , -1148.76430102, -1154.40987853, -1159.41284399,
#         -1163.7334545 , -1167.35302176, -1170.27323466, -1172.51497333,
#         -1174.11667116, -1175.13222058, -1175.62839127, -1175.68175982,
#         -1175.37522878, -1174.79431123, -1174.02343165, -1173.14251792,
#         -1172.22412428, -1171.33124633, -1170.51589295, -1169.81839157,
#         -1169.26734009, -1168.88008825, -1168.6636285 , -1168.6157942 ,
#         -1168.72668481, -1168.98025359, -1169.35599464, -1169.83065525,
#         -1170.37988412, -1170.97971822, -1171.60781897, -1172.24439374,
#         -1172.87277588, -1173.47967648, -1174.0551542 , -1174.59237028]),
#  'split1_test_score': array([-5820.46362163, -5776.34408654, -5725.39329305, -5666.73824126,
#         -5599.45879663, -5522.60901806, -5435.24795164, -5336.4813144 ,
#         -5225.51488391, -5101.71931636, -4964.70445827, -4814.39900577,
#         -4651.12877493, -4475.68427284, -4289.366337  , -4093.99814354,
#         -3891.8936478 , -3685.77695914, -3478.65404611, -3273.64643681,
#         -3073.80436857, -2881.92200024, -2700.37810719, -2531.02155917,
#         -2375.11273583, -2233.32201339, -2105.77720467, -1992.14557637,
#         -1891.73388393, -1803.59148335, -1726.60567302, -1659.58324872,
#         -1601.31634008, -1550.63315215, -1506.4352498 , -1467.7230199 ,
#         -1433.61061153, -1403.33150146, -1376.23604418, -1351.78282351,
#         -1329.52604836, -1309.10136769, -1290.21219421, -1272.61797732,
#         -1256.12503723, -1240.5797992 , -1225.86373739, -1211.8891417 ,
#         -1198.59493726, -1185.94210944, -1173.90867687, -1162.4844802 ,
#         -1151.66623031, -1141.45326288, -1131.84430787, -1122.83537274,
#         -1114.41863257, -1106.58208073, -1099.30964725, -1092.58153538,
#         -1086.37462843, -1080.66293918, -1075.41817068, -1070.61050089,
#         -1066.20968004, -1062.18644711, -1058.51415803, -1055.17041291,
#         -1052.1384131 , -1049.40779366, -1046.97476183, -1044.84150233,
#         -1043.01494692, -1041.50511295, -1040.32326839, -1039.48017422,
#         -1038.98459962, -1038.84222284, -1039.05494568, -1039.6205808 ,
#         -1040.53282673, -1041.78142479, -1043.35238736, -1045.22819521,
#         -1047.38788271, -1049.80697084, -1052.45726894, -1055.30663961,
#         -1058.31888427, -1061.45393389, -1064.66849832, -1067.91724053,
#         -1071.1544189 , -1074.33582154, -1077.42073885, -1080.3737068 ,
#         -1083.16580355, -1085.77537404, -1088.18816242, -1090.39692179]),
#  'split2_test_score': array([-5374.07835427, -5326.90327912, -5272.46486282, -5209.85013845,
#         -5138.10306279, -5056.24932713, -4963.33159525, -4858.45661255,
#         -4740.8548966 , -4609.95244252, -4465.45197684, -4307.41880237,
#         -4136.36341242, -3953.31028531, -3759.84032957, -3558.0942371 ,
#         -3350.72634791, -3140.80396166, -2931.65499278, -2726.67613789,
#         -2529.12216574, -2341.902167  , -2167.40881551, -2007.40144625,
#         -1862.95424783, -1734.46959413, -1621.74641096, -1524.08679684,
#         -1440.42189345, -1369.43979203, -1309.70261126, -1259.74502548,
#         -1218.15103778, -1183.60896012, -1154.94634908, -1131.14745005,
#         -1111.35602315, -1094.86662348, -1081.10761496, -1069.61935111,
#         -1060.03090715, -1052.03836891, -1045.38694405, -1039.85815   ,
#         -1035.2622343 , -1031.43501276, -1028.23765159, -1025.55766974,
#         -1023.30959139, -1021.43414181, -1019.89550365, -1018.67677046,
#         -1017.77421406, -1017.1912359 , -1016.93288372, -1017.00162711,
#         -1017.39478323, -1018.1036638 , -1019.11425394, -1020.40907115,
#         -1021.96978915, -1023.78021362, -1025.82922763, -1028.11335653,
#         -1030.63863105, -1033.42146812, -1036.48836155, -1039.87428979,
#         -1043.61989687, -1047.767659  , -1052.35738359, -1057.42147463,
#         -1062.98043492, -1069.03906591, -1075.58378292, -1082.58138909,
#         -1089.97953977, -1097.70897233, -1105.68737544, -1113.8245495 ,
#         -1122.0283048 , -1130.21040326, -1138.29181323, -1146.20663097,
#         -1153.90422126, -1161.34940773, -1168.52085326, -1175.40805419,
#         -1182.0075746 , -1188.31922918, -1194.34286533, -1200.07621303,
#         -1205.51400813, -1210.64831708, -1215.46976667, -1219.96925709,
#         -1224.13972549, -1227.9776104 , -1231.48380336, -1234.66401872]),
#  'split3_test_score': array([-5356.19398034, -5309.34719446, -5255.29266369, -5193.12629484,
#         -5121.90212192, -5040.65719805, -4948.44688781, -4844.39199047,
#         -4727.73838907, -4597.92864179, -4454.68303126, -4298.08509394,
#         -4128.66378082, -3947.46161826, -3756.0762696 , -3556.66264367,
#         -3351.88500194, -3144.81383201, -2938.77027457, -2737.1303398 ,
#         -2543.10990551, -2359.55711974, -2188.77939998, -2032.42708321,
#         -1891.44596007, -1766.09887424, -1656.04536209, -1560.46060793,
#         -1478.17220833, -1407.79521053, -1347.85116027, -1296.86340084,
#         -1253.42672344, -1216.25352204, -1184.20059091, -1156.28104676,
#         -1131.66529122, -1109.67411932, -1089.76641822, -1071.52348299,
#         -1054.63170974, -1038.86516327, -1024.06916664, -1010.14562082,
#          -997.04030757,  -984.73205433,  -973.22342456,  -962.53256726,
#          -952.68598731,  -943.71221234,  -935.63654338,  -928.47720496,
#          -922.24320974,  -916.93411474,  -912.54160368,  -909.05254074,
#          -906.45287595,  -904.73161005,  -903.88399741,  -903.91329627,
#          -904.83064536,  -906.65299454,  -909.39937085,  -913.08604653,
#          -917.72134708,  -923.30087858,  -929.80387496,  -937.19119519,
#          -945.40526961,  -954.37203685,  -964.00465729,  -974.20856225,
#          -984.88722593,  -995.94795127, -1007.30695983, -1018.89317498,
#         -1030.65027599, -1042.53684537, -1054.5246905 , -1066.59564628,
#         -1078.73732826, -1090.93839131, -1103.18386254, -1115.45107382,
#         -1127.70663417, -1139.90476636, -1151.98719219, -1163.88459104,
#         -1175.5194842 , -1186.81023014, -1197.67567605, -1208.03992784,
#         -1217.83669585, -1227.0127543 , -1235.5302033 , -1243.36741141,
#         -1250.51870312, -1256.99300267, -1262.81173392, -1268.00630028]),
#  'split4_test_score': array([-4888.00981796, -4848.00127353, -4801.82862963, -4748.71450597,
#         -4687.84318284, -4618.3807245 , -4539.50354987, -4450.43655241,
#         -4350.50124453, -4239.17334294, -4116.14767122, -3981.40628389,
#         -3835.28351564, -3678.51962662, -3512.29343776, -3338.22450452,
#         -3158.33753792, -2974.98614085, -2790.73905347, -2608.23884645,
#         -2430.04870836, -2258.50596836, -2095.60021976, -1942.88939371,
#         -1801.46006964, -1671.9306401 , -1554.48965308, -1448.95806811,
#         -1354.86360754, -1271.51723741, -1198.08490367, -1133.65077307,
#         -1077.27055881, -1028.01477819,  -985.00219949,  -947.42374088,
#          -914.55711402,  -885.77279494,  -860.53244489,  -838.38151096,
#          -818.93817106,  -801.8808717 ,  -786.93638982,  -773.86972291,
#          -762.47635772,  -752.57679427,  -744.01276161,  -736.64441703,
#          -730.34793455,  -725.01316008,  -720.54131399,  -716.84295156,
#          -713.83648423,  -711.44751128,  -709.6090501 ,  -708.26255056,
#          -707.35940782,  -706.86260157,  -706.74810711,  -707.00582442,
#          -707.63990907,  -708.66850894,  -710.12297358,  -712.04659517,
#          -714.49287887,  -717.52326359,  -721.2041699 ,  -725.60327683,
#          -730.78504002,  -736.80564075,  -743.70775066,  -751.51564434,
#          -760.23123213,  -769.83149407,  -780.26759052,  -791.46566731,
#          -803.32913735,  -815.74207127,  -828.57329421,  -841.68085081,
#          -854.91661893,  -868.13096539,  -881.1773963 ,  -893.91713848,
#          -906.22351299,  -917.98586512,  -929.11275075,  -939.53408346,
#          -949.20203437,  -958.09062595,  -966.19413181,  -973.52453932,
#          -980.10841716,  -985.98354461,  -991.19561383,  -995.7952346 ,
#          -999.83537873, -1003.36931957, -1006.44905976, -1009.12420187]),
#  'mean_test_score': array([-5382.95460393, -5338.25928647, -5286.66925945, -5227.31286263,
#         -5159.27516614, -5081.62076393, -4993.42631497, -4893.82421552,
#         -4782.05811765, -4657.54983734, -4519.97544306, -4369.34600879,
#         -4206.08584795, -4031.09844598, -3845.80844854, -3652.16776991,
#         -3452.61594571, -3249.98967949, -3047.38384012, -2847.9747761 ,
#         -2654.82477368, -2470.69157876, -2297.86739705, -2138.06716344,
#         -1992.37713416, -1861.2642705 , -1744.6371927 , -1641.94295931,
#         -1552.28165949, -1474.52249526, -1407.40932729, -1349.64880624,
#         -1299.97872072, -1257.21724442, -1220.29527648, -1188.2744686 ,
#         -1160.35341095, -1135.86427712, -1114.26221298, -1095.10986157,
#         -1078.05947779, -1062.8349366 , -1049.21550108, -1037.02254089,
#         -1026.1096178 , -1016.35565843, -1007.6604567 ,  -999.94155884,
#          -993.13166761,  -987.17597918,  -982.02922331,  -977.65250407,
#          -974.01025414,  -971.06768413,  -968.78904007,  -967.13682008,
#          -966.07190966,  -965.55443101,  -965.5450094 ,  -966.00614944,
#          -966.90347422,  -968.20667609,  -969.89012228,  -971.93312356,
#          -974.31989993,  -977.03927168,  -980.08408859,  -983.45040374,
#          -987.13641482,  -991.1412304 ,  -995.46355761, -1000.10043138,
#         -1005.04610221, -1010.29116895, -1015.82199859, -1021.62043308,
#         -1027.6637563 , -1033.92488461, -1040.3727475 , -1046.97282906,
#         -1053.6878406 , -1060.47848622, -1067.30427048, -1074.12428601,
#         -1080.89791825, -1087.58541966, -1094.14833873, -1100.5498325 ,
#         -1106.75493245, -1112.73085455, -1118.44743323, -1123.87771519,
#         -1128.99868483, -1133.79203115, -1138.24482832, -1142.35000073,
#         -1146.10647735, -1149.51899663, -1152.59758273, -1155.35676259]),
#  'std_test_score': array([298.6107557 , 297.24786811, 295.68358676, 293.89569689,
#         291.86216559, 289.56219261, 286.97756182, 284.09427562,
#         280.90439377, 277.40791098, 273.61439774, 269.5440149 ,
#         265.22743101, 260.70418266, 256.01919501, 251.21757865,
#         246.33842662, 241.40901495, 236.44127781, 231.43234258,
#         226.37004354, 221.24279464, 216.05149608, 210.82000482,
#         205.60069955, 200.47293623, 195.5342953 , 190.88669447,
#         186.6209024 , 182.8032597 , 179.46748553, 176.61275777,
#         174.20747919, 172.19689695, 170.5123179 , 169.07996686,
#         167.82823381, 166.69279515, 165.61964871, 164.56641181,
#         163.50233947, 162.40750635, 161.2715297 , 160.09212964,
#         158.87374267, 157.62632301, 156.36438419, 155.10625277,
#         153.87343705, 152.6899682 , 151.58155757, 150.57443702,
#         149.6938054 , 148.96188739, 148.39570949, 148.00479545,
#         147.78905989, 147.73721224, 147.82595659, 148.02018372,
#         148.27421378, 148.53399319, 148.74001223, 148.8306227 ,
#         148.7454123 , 148.42833463, 147.83038323, 146.91170835,
#         145.64317615, 144.00743452, 141.99956586, 139.62737908,
#         136.91134231, 133.88411492, 130.58962537, 127.08167063,
#         123.42207098, 119.6784787 , 115.92198109, 112.22464057,
#         108.65707467, 105.28611434, 102.1725221 ,  99.3687373 ,
#          96.91666649,  94.8456464 ,  93.17083546,  91.89236974,
#          90.9955914 ,  90.4525003 ,  90.22433633,  90.2649589 ,
#          90.52453973,  90.95307091,  91.50329587,  92.13284044,
#          92.80549354,  93.49171916,  94.16855791,  94.81910203]),
#  'rank_test_score': array([100,  99,  98,  97,  96,  95,  94,  93,  92,  91,  90,  89,  88,
#          87,  86,  85,  84,  83,  82,  81,  80,  79,  78,  77,  76,  75,
#          74,  73,  72,  71,  70,  69,  68,  67,  66,  65,  64,  57,  52,
#          48,  44,  41,  38,  35,  32,  30,  27,  24,  22,  20,  17,  15,
#          12,  10,   8,   6,   4,   2,   1,   3,   5,   7,   9,  11,  13,
#          14,  16,  18,  19,  21,  23,  25,  26,  28,  29,  31,  33,  34,
#          36,  37,  39,  40,  42,  43,  45,  46,  47,  49,  50,  51,  53,
#          54,  55,  56,  58,  59,  60,  61,  62,  63], dtype=int32)}

# %% [markdown]
# ### Task 1d)
# In the code block below, you will find a function `elnet_cvplot_1d` which plots cross-validation errors together with bands at a distance of one standard deviation. It also indicates the position of the tuning parameter value with minimal cross-validation error and of the value that would be chosen according to the one-S.E. rule. The function is almost complete - you only need to do the following:
#
# 1. Ensure that the object `min_error_index` contains the index of the tuning parameter leading to the smallest cross-validation error. `argmin()` in NumPy does that for you.
# 2. Allocate to `one_se_rule_index` the index of the tuning parameter value that would be chosen according to the one-standard error rule. You could do that by using the NumPy function `where()` to ask which cross-validation errors are smaller than the minimum cross-validation error plus one standard error. The last element in the resulting array should contain the index that you are looking for.
# 3. Create a dictionary object `best_lams` with elements "lambda_min" and "lambda_1se" which contain the values of the tuning parameter suggested by minimum cross-validation error and the one-S.E. rule, respectively. Tell your python function to return `best_lams`.

# %%
def elnet_cvplot_1d(lambdas, cv_errors, std_errors):
    """
    Inputs:
    - lambdas: Array of tuning parameter values.
    - cv_errors: Array of cross-validation errors corresponding to tuning parameters.
    - std_errors: Array of standard errors of cross-validation errors.
    """
    # Do not change anything in the following six lines
    sort_idx   = np.argsort(lambdas)
    lambdas    = lambdas[sort_idx]
    cv_errors  = cv_errors[sort_idx]
    std_errors = std_errors[sort_idx]
    
    plt.figure(figsize=(10, 6))
    plt.plot(lambdas, cv_errors, linestyle='-', color='blue', label='CV Error')
    
    upper_band = np.array(cv_errors) + np.array(std_errors)
    lower_band = np.array(cv_errors) - np.array(std_errors)
    plt.fill_between(lambdas, lower_band, upper_band, color='gray', alpha=0.6, label='±1 SE')

    # 1. Find index of minimum CV error
    min_error_index = np.argmin(cv_errors)
    plt.axvline(x=lambdas[min_error_index], color='gray', linestyle='--', label='Min Error')

    # 2. Find the index for the one-standard error rule 
    one_se_rule_index = np.where(cv_errors < (cv_errors[min_error_index] + std_errors[min_error_index]))[0][-1]
    plt.axvline(x=lambdas[one_se_rule_index], color='red', linestyle=':', label='1SE rule')
    
    # Do not change the seven lines below
    plt.xscale('log')
    plt.xlabel('Regularization parameter values')
    plt.ylabel('Cross-Validation error')
    plt.title('Cross-Validation Error with One Standard Error Bands')
    plt.legend()
    plt.grid(True)   
    plt.show()

    # 3. Return best lambda values in a dictionary
    best_lams = {
        'lambda_min': lambdas[min_error_index],
        'lambda_1se': lambdas[one_se_rule_index]
    }

    return best_lams

# %% [markdown]
# ### Task 1e)
# Call the function `elnet_cvplot_1d` in order to obtain a plot of tuning parameter values against cross-validation error. Save the result as `ridge_best_lambdas_1e`. The arrays of cross-validation errors and their standard errors are saved inside `ridge_cv_out_1c`. Choose them correctly when calling `elnet_cvplot_1d` and make sure that your cross-validation errors are positive numbers.
#
# Lastly, judging from the regularization path from Task 1b, how much are the learned model coefficients shrunk to zero relative to a linear regression model without regularization? Save your answer as string variable `regularization_amount_1e`.

# %%
ridge_best_lambdas_1e = elnet_cvplot_1d(lambdas_1c, -ridge_cv_out_1c['mean_test_score'] , ridge_cv_out_1c['std_test_score']) 
print(ridge_best_lambdas_1e)
regularization_amount_1e = """
At lambda_min (10.57), the coefficients are moderately shrunk compared to a linear regression model without regularization, but many retain significant values. 
At lambda_1se (232.99), much heavier regularization is applied, shrinking most coefficients closer to zero, resulting in a simpler model with fewer influential predictors. 
This shows that as the regularization strength increases, more coefficients are driven towards zero, limiting their impact on the model.
"""
# Out:
# {'lambda_min': 10.565735818049962, 'lambda_1se': 232.98828842076622}

# %% [markdown]
# ### Task 1f)
# Now, we want to get test set predictions for ridge regression with tuned regularization parameter. To arrive there, do the following:
#
# 1. Fit ridge regression with your personal favorite among the minimum-MSE or one-S.E. tuning parameter values. This merely requires you to specifiy a modified version of `ridge_pipe_1c` and to apply the `fit()`-method to the resulting pipeline. Save the learned model as `ridge_fit_1f`.
# 2. Apply the `predict()` method to `ridge_fit_1f` in order to get output predictions for all data points in `X_test_1a`. Save them as `yhat_test_ridge_1f`.

# %%
# 1.
ridge_fit_1f  = Pipeline([('transformations', X_transform_pipe_1b),('ridge', Ridge(alpha=ridge_best_lambdas_1e['lambda_min']))]).fit(X_train_1a, y_train_1a)
# 2.
yhat_test_ridge_1e  = ridge_fit_1f.predict(X_test_1a)

# %% [markdown]
# ## Part 2: Lasso with scikit-learn
#
# In this slightly more difficult section, we are going to repeat Part 1 for the lasso and improvise a little with the model specification.
#
#
# ### Task 2a)
#
# Repeat Tasks 1c, 1e and 1f, albeit for the lasso instead of ridge regression. That is, do the following:
#
# 1. Specify a pipeline for the lasso. Save as `lasso_pipe_2a`.
# 2. Turn the provided array of tuning parameter candidates `lambdas_2a` into a tuning grid that works with `lasso_pipe_2a`. Save as `tune_grid_2a`.
# 3. Conduct cross-validation. You can reuse the splitter `cv_splits_1c`. Save as `lasso_tune_2a`.
# 4. Extract detailed cross-validation results into `lasso_cv_out_2a`.
# 5. Call `elnet_cvplot_1d` and save results as `lasso_best_lambdas_1e`. Decide whether minimum-MSE or one-S.E. choice is most suitable and explain shortly in the string variable `bestlambda_lasso_2a`.
# 6. Set up a pipeline for Lasso with your optimal regularization parameter and learn this model in the training data. Save as `lasso_fit_2a`.
# 7. Obtain test data predictions `yhat_test_lasso_2a`.

# %%
from sklearn.linear_model import (ElasticNet, Lasso)


# 1.
lasso_pipe_2a = Pipeline([('transformations', X_transform_pipe_1b),('lasso', Lasso(max_iter = 100000))])

# 2.
lambdas_2a = 10**np.linspace(2,-3)
tune_grid_2a = {'lasso__alpha': lambdas_2a}

# 3.
lasso_tune_2a = GridSearchCV(lasso_pipe_2a, param_grid=tune_grid_2a, cv=cv_splits_1c, scoring='neg_mean_squared_error')
lasso_tune_2a.fit(X_train_1a, y_train_1a)

# 4.
lasso_cv_out_2a  = lasso_tune_2a.cv_results_

# 5. 
lasso_best_lambdas_2a  = elnet_cvplot_1d(lambdas_2a, -lasso_cv_out_2a['mean_test_score'], lasso_cv_out_2a['std_test_score'])

# 6. 
lasso_fit_2a = Pipeline([('transformations', X_transform_pipe_1b), ('lasso', Lasso(alpha=lasso_best_lambdas_2a['lambda_min'],max_iter = 10000))]).fit(X_train_1a, y_train_1a)
bestlambda_lasso_2a = """The one-standard-error (one-S.E.) rule is a better option because it helps prevent overfitting. 
                         While the minimum-MSE choice selects the lambda value that results in the lowest error on the training data, 
                         it risks overfitting to that data. Although the one-S.E. method may lead to a slightly higher error on the training set, 
                         it reduces the risk of overfitting and is more likely to reflect the true underlying distribution of the data."""

# 7.
yhat_test_lasso_2a = lasso_fit_2a.predict(X_test_1a)

# %% [markdown]
# ### Task 2b)
#
# The performance of regularized linear regression models crucially depends on which input variables we use. We already exploited this fact by adding interactions between any two variables in `X_train_1a` to our model inputs. Now, we additionally use the principal components of the original data and therefore create a hybrid between regularization and dimension reduction.
#
# Our key tool in `sklearn` for this task is be the `FeatureUnion()` function. It is specified like a pipeline, but it does not *sequentially* apply the transformations that it consists of. Instead `FeatureUnion()` executes the transformations in parallel and combines their output.
#
# Now conduct the following steps:
#
# 1. Create a pipeline `pca_pipe_2b` which obtains all principal components of the data it is fit on. In addition to conducting PCA, the pipeline should standardize the data before **and** after getting principal components. `pca_pipe_2b` is a pipeline for pure variable transformation, just as `X_transform_pipe_1b` in Task 1b was.
# 2. Use the `FeatureUnion()` to combine the pipelines `X_transform_pipe_1b` and `pca_pipe_2b` and save the resulting specification as `combined_transform_2b`.
# 3. Write a pipeline that conducts the data transformation `combined_transform_2b` and which subsequently trains a lasso model. Save this pipeline as `lasso_pipe_2b`.

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import FeatureUnion

# 1.
pca_pipe_2b =  Pipeline([('standardize', StandardScaler()),('pca', PCA()),('standardize_after_pca', StandardScaler())])

# 2.
combined_transform_2b = FeatureUnion([('original_features', X_transform_pipe_1b),('pca_features', pca_pipe_2b)])

# 3.
lasso_pipe_2b = Pipeline([('transformations', combined_transform_2b),('lasso', Lasso())])

# %% [markdown]
# ### Task 2c)
# Run 5-fold cross-validation as in Task 2a when you created the object `lasso_tune_2a`. However, use your new pipeline `lasso_pipe_2b` as estimator. Save the resulting object as `lasso_tune_2c`.
#
# Then, let's skip the process of looking at the curve of cross-validation errors and of deciding between minimum MSE and one-S.E. tuning parameter values. Once fitted, an object created with `GridSearchCV()` allows you to directly get predictions from the model with tuning parameter that minimizes cross-validation error. You only need to apply the `predict()` method to this object. Do this now in order to get output predictions for the test inputs `X_test_1a`. Save your predictions as `yhat_test_lasso_2c`.

# %%
lasso_tune_2c = GridSearchCV(lasso_pipe_2b, param_grid=tune_grid_2a, cv=cv_splits_1c, scoring='neg_mean_squared_error')
lasso_tune_2c.fit(X_train_1a, y_train_1a)

yhat_test_lasso_2b = lasso_tune_2c.predict(X_test_1a)
# Out:
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.670e+02, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.280e+03, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.422e+02, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.023e+03, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.255e+02, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+03, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.239e+03, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.160e+03, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.562e+03, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.284e+03, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.676e+03, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.254e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.177e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.089e+04, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.169e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.376e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.050e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.076e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.788e+04, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.538e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.210e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.947e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.504e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.547e+04, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.179e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.991e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.463e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.638e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.783e+04, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.479e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.428e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.391e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.975e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.338e+04, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.208e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.753e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.803e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.653e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.178e+04, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.402e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.272e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.571e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.400e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.913e+04, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.489e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.173e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.499e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.931e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.484e+04, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.983e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.844e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.335e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.310e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.041e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.737e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.339e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.035e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.643e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.082e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.426e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.734e+04, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.644e+04, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.964e+04, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.117e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.964e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.006e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.014e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.028e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.145e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.427e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.037e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.051e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.171e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.832e+04, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.063e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.193e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.018e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.083e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.103e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.101e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.211e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.047e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.099e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.122e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.119e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.226e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.068e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.112e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.135e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.134e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.239e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.086e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.122e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.146e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.146e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ### Task 2d
# Lasso performs variable selection in addition to shrinkage. For this reason, we move outside our prediction-centered machine learning bubble for a second and have a look at the input variables that are included in our chosen lasso model from Task 2c.
#
# The model with best tuning parameter is saved as an attribute in `lasso_tune_2b`. Look up in the [GridSearchCV documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) which attribute that is and save it as an object `lasso_fit_2d`.
#
# The learned coefficients of the lasso model are saved as an attribute inside `lasso_fit_2d`. Look up the documentation for [Lasso](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html) or [ElasticNet](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html) (depending on which function you used) to identify the correct attribute. Then, note that your estimator is an entire pipeline. For that reason, address the last step of this pipeline (by name) and save the attribute which contains its learned coefficients as a new object `lasso_coefs_2d`.

# %%
# Set pandas to display more digits after the decimal point
pd.options.display.float_format = '{:.6f}'.format

lasso_fit_2d = lasso_tune_2c.best_estimator_

lasso_coefs_2d = lasso_fit_2d.named_steps['lasso'].coef_

# Run the four lines below to match variable names with coefficient values.
poly_feature_names  = X_transform_pipe_1b['poly_features'].get_feature_names_out(input_features=X_train_1a.columns)
pca_component_names = [f'PC{idx}' for idx in range(1, X_train_1a.shape[1] + 1)]
all_feature_names   = np.concatenate([poly_feature_names, pca_component_names])
lasso_coefs_2d      = pd.DataFrame({'Variable': all_feature_names, 'Coefficient': lasso_coefs_2d})

print(lasso_coefs_2d)
# Out:
#      Variable  Coefficient
# 0      COUPON     0.000000
# 1         NEW     0.000000
# 2          HI     0.000000
# 3    S_INCOME     0.000000
# 4    E_INCOME     0.000000
# ..        ...          ...
# 99        PC9     0.000000
# 100      PC10     0.000000
# 101      PC11    -0.000000
# 102      PC12     0.000000
# 103      PC13    -0.000000
#
# [104 rows x 2 columns]

# %% [markdown]
# ## Part 3: Elastic net and overall performance evaluation
#
# Now that we successfully tuned both ridge regression and the lasso, doing the same for the elastic net is very simple.

# %% [markdown]
# ### Task 3a)
#
# Conduct the following tasks to set up your cross-validation setup.
#
# 1. Create a pipeline with the same setup as in `ridge_pipe_1c` or `lasso_pipe_2a` except for specifying the elastic net in the last step. Save the object as `elnet_pipe_3a`.
# 2.  Create a dictionary `tune_grid_3a` concerning candidate values of your two tuning parameters. The names of this dictionary should be chosen so that they work with `elnet_pipe_3a`. The candidate values for the regularization parameter can be those saved in `lambdas_2a`. For the `l1_ratio` parameter that weights l1- and l2-penalties, choose six values from 0 to 1 with equal distance to each other.

# %%
# 1.
elnet_pipe_3a = Pipeline([('transformations', combined_transform_2b),('elastic_net', ElasticNet())])
# 2.
l1_ratios = np.linspace(0, 1, 6)
tune_grid_3a  = {
    'elastic_net__alpha': lambdas_2a,
    'elastic_net__l1_ratio': l1_ratios
}

# %% [markdown]
# ### Task 3b)
# The two objects created in Task 3a are all inputs to `GridSearchCV()` that are specific to elastic net.
#
# First, specify and fit an object `elnet_tune_3b` with `GridSearchCV()`. The criterion for predictive accuracy and the split into five folds should be the same as before.
#
# Second, look in the [GridSearchCV() documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) for the attribute in `elnet_tune_3b` which contains the best tuning parameter values. Save this attribute as `tune_elnet_best_3b`. Do the chosen tuning parameter values result in a model that leans more into the direction of ridge regression or more towards the lasso? Write a well-motivated answer into the string variable `interpret_tune_3b`.
#
# Third, get predictions for the test inputs `X_test_1a` from `elnet_tune_3b` (i.e. from the model that leads to minimum cross-validation error). Save them as `yhat_test_elnet_3b`.

# %%
# 1.
elnet_tune_3b = GridSearchCV(elnet_pipe_3a, param_grid=tune_grid_3a, cv=cv_splits_1c, scoring='neg_mean_squared_error')
elnet_tune_3b.fit(X_train_1a, y_train_1a)

# 2.
tune_elnet_best_3b = elnet_tune_3b.best_params_
interpret_tune_3b = """ The best tuning parameters result in a model that leans entirely towards Lasso regression. The l1_ratio is set to 1.0, which means the regularization consists solely of the L1 penalty (no L2 penalty), making it a pure Lasso model. This leads to feature selection, where some coefficients are driven to zero, rather than the overall shrinkage of coefficients as seen in Ridge regression."""

# 3.
yhat_test_elnet_3b = elnet_tune_3b.predict(X_test_1a)
tune_elnet_best_3b
# Out:
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.049e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.939e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.138e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.109e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.287e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.849e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.741e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.936e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.906e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.075e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.613e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.507e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.697e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.667e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.826e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.339e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.235e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.420e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.389e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.537e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.024e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.923e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.103e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.071e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.209e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.671e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.574e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.747e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.715e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.842e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.282e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.190e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.356e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.323e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.441e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.865e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.777e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.936e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.903e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.013e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.426e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.344e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.495e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.463e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.567e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.976e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.900e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.044e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.012e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.113e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.527e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.456e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.593e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.562e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.661e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.088e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.022e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.152e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.123e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.223e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.669e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.607e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.731e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.705e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.807e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.277e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.219e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.337e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.314e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.419e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.919e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.862e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.975e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.956e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.064e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.595e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.540e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.648e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.633e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.744e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.306e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.252e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.356e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.345e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.460e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.053e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.100e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.169e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.166e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.269e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.068e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.112e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.135e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.134e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.239e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.200e+05, tolerance: 1.987e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.207e+05, tolerance: 1.964e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.234e+05, tolerance: 2.007e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.257e+05, tolerance: 2.002e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.342e+05, tolerance: 2.047e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.183e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.191e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.219e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.238e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.165e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.205e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.219e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.309e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.142e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.158e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.191e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.197e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.292e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.107e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.173e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.173e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.273e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.086e+05, tolerance: 1.987e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.122e+05, tolerance: 1.964e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.146e+05, tolerance: 2.007e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.146e+05, tolerance: 2.002e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/georgetsoupras/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+05, tolerance: 2.047e+02
#   model = cd_fast.enet_coordinate_descent(
# {'elastic_net__alpha': 0.28117686979742307, 'elastic_net__l1_ratio': 1.0}

# %% [markdown]
# ### Task 3c)
#
# We have now obtained predictions on test data for four different versions of the elastic net. It is time to find out which of them performs best. Use the observed test outcomes `y_test_1a` to calculate the mean squared error for all `yhat_test`-objects that we have created so far. You can calculate MSE manually or use the `mean_squared_error` function in the metrics module of `sklearn`. Save them as `MSE_` plus the name of the method that we used previously.
#
# Which one among the four candidate algorithms is superior? Write your conclusion and some details about the margin between the best and the remaining algorithms in the string variable `conclusion_3c`.

# %%
from sklearn.metrics import mean_squared_error

MSE_ridge   = mean_squared_error(y_test_1a, yhat_test_ridge_1e)
MSE_lasso_a = mean_squared_error(y_test_1a, yhat_test_lasso_2a)
MSE_lasso_b = mean_squared_error(y_test_1a, yhat_test_lasso_2b)
MSE_elnet   = mean_squared_error(y_test_1a, yhat_test_elnet_3b)

# Print MSE values
print("MSE for Ridge :", MSE_ridge)
print("MSE for Lasso (2a):", MSE_lasso_a)
print("MSE for Lasso (2c):", MSE_lasso_b)
print("MSE for Elastic Net :", MSE_elnet)
conclusion_3c = "The Elastic Net and the second Lasso model (Lasso_b) deliver the best predictive performance, with identical MSE values of 917.9177, suggesting that the combination of L1 and L2 regularization in Elastic Net is particularly effective for this dataset. The first Lasso model (Lasso_a) comes close with an MSE of 917.9777, while Ridge regression performs the worst with an MSE of 927.0222. The small margin between the best and worst models indicates that all approaches perform reasonably well, but Elastic Net and Lasso benefit from their ability to perform feature selection, improving prediction accuracy. Ridge regression lags behind because it retains all features, some of which may be less relevant or predictive. This suggests that sparsity, as encouraged by Lasso and Elastic Net, plays a crucial role in improving prediction accuracy for this dataset."
# Out:
# MSE for Ridge : 927.0221770806062
# MSE for Lasso (2a): 917.9776810164318
# MSE for Lasso (2c): 917.9177047831922
# MSE for Elastic Net : 917.9177047831922

# %% [markdown]
# ## Part 4: Manual cross-validation for ridge regression
#
# In this really advanced part, we are going to manually conduct the grid search over tuning parameter values that `GridSearchCV()` automatically provides us with. We are going to find the optimal tuning parameter for ridge regression. The learning goal of this part is to realize what a gigantic mess machine learning life is without `sklearn` (or similar libraries).

# %% [markdown]
# ### Task 4a)
# Write a function `ridge_testMSE_4a` that takes the following inputs:
#
# - `Xtrain`: training inputs
# - `ytrain`: training output
# - `Xtest`:  test inputs
# - `ytest`:  test outputs
# - `lam`:    tuning parameter value
#
# The function is supposed to do the following:
# 1. Set the current tuning parameter value `lam` as the `alpha`-argument of your ridge regression estimator in `ridge_pipe_1c`. The `set_params()`-method allows you to do this. The name of the `alpha` argument must be specified as `xyz__alpha` where you **replace xyz** with the name that you gave the ridge regression step in `ridge_pipe_1c`.
# 2. Fit the pipeline `ridge_pipe_1c` from Part 1 on the training data. Specify the current tuning parameter value `lam` as an additional argument to the fit-method.
# 3. Use the fitted model to predict outputs for the test inputs.
# 4. Calculate the MSE and return it as function output.

# %%
def ridge_testMSE_4a(Xtrain, ytrain, Xtest, ytest, lam):
    
    ridge_pipe_1c.set_params(ridge__alpha=lam)

    ridge_pipe_1c.fit(Xtrain, ytrain)

    y_pred = ridge_pipe_1c.predict(Xtest)

    mse = mean_squared_error(ytest, y_pred)

    return mse

# %% [markdown]
# ### Task 4b)
# Write a function `ridge_testMSE_grid_4b` that takes the same inputs as `ridge_testMSE_4a` except that it takes an entire array of tuning parameter values `lam_grid` instead of one value `lam`. For each value in `lam_grid` it gets test MSE from `ridge_testMSE_4a`. The entire NumPy array of test MSEs is then returned as function output.

# %%
def ridge_testMSE_grid_4b(Xtrain, ytrain, Xtest, ytest, lam_grid):
    
    mse_values = [] 

    for lam in lam_grid:
        mse = ridge_testMSE_4a(Xtrain, ytrain, Xtest, ytest, lam)
        mse_values.append(mse)

    return np.array(mse_values)

# %% [markdown]
# ### Task 4c)
#
# Write a function `ridge_kfolderr_4c` that takes the following inputs:
#
# - `X`: a matrix of model inputs,
# - `y`: a vector of model outputs,
# - `lamgrid:`a vector of tuning parameter values,
# - `batchid`: A vector that specifies to which batch a particular data point belongs to.
#
# `ridge_kfolderr_4c` should first identify $K$ as the maximum value in `batchid`. Then it should loop over the values $1,2,\ldots,K$. At iteration $k$, the loop should do the following:
#
# 1. Set `X_train` (`y_train`) as all data points in `X` (`y`) that do *not* belong to batch $k$,
# 2. Set `X_test` (`y_test`) as all data points in `X` (`y`) that *belong* to batch $k$.
# 3. Call `ridge_testMSE_grid_4c` for the given split into training and test batches to get test MSEs for the entire vector `lamgrid`.
#
# Once the loop has finished, the test MSEs of all $K$ iterations should be averaged. The resulting vector of k-fold cross-validation errors should be the function output.

# %%
def ridge_kfolderr_4c(X, y, lamgrid, batchid):

    K = max(batchid)
    mse_values = []

    for k in range(1, K+1):
        X_train = X[batchid != k]
        y_train = y[batchid != k]
        X_test = X[batchid == k]
        y_test = y[batchid == k]

        mse_grid = ridge_testMSE_grid_4b(X_train, y_train, X_test, y_test, lamgrid)

        mse_values.append(mse_grid)

    avg_mse_values = np.mean(np.array(mse_values), axis=0)

    return avg_mse_values

# %% [markdown]
# ### Task 4d)
#
# Below, I specify `lamgrid_4d`, a grid of potential values for $\lambda$, as well as `batches_4d`, an allocation of data points to batches. Do the following:
#
# 1. Use `ridge_kfolderr_4c` with these inputs as well as `y_train_1a` and `X_train_1a` to get k-fold CV errors for every tuning parameter value in `lamgrid_4d`. Save this object as `kfolderrs_4d`.
# 2. Use `which.min()` to extract the index of the smallest k-fold CV value in `kfolderrs_4d` into a new object `minindex_4d`.
# 3. Save the k-fold CV error at index `minindex_4d` of `lamgrid_4d` as `best_lambda_4d`.

# %%
lamgrid_4d = np.logspace(4, -3, 100)/y_train_1a.std(ddof=1)
np.random.seed(5)
batches_4d = np.random.randint(1, 6, size =y_train_1a.shape[0])

kfolderrs_4d = ridge_kfolderr_4c(X_train_1a, y_train_1a, lamgrid_4d, batches_4d)
minindex_4d = np.argmin(kfolderrs_4d)
best_lambda_4d = lamgrid_4d[minindex_4d]


print("K-fold CV Errors:", kfolderrs_4d)
print("Best Lambda:", best_lambda_4d)

print("Index of minimum k-fold CV value:", minindex_4d)
# Out:
# K-fold CV Errors: [1061.89230113 1052.01415406 1043.38677595 1035.89105106 1029.43339133
#  1023.94391633 1019.37415513 1015.69380185 1012.88654117 1010.94533837
#  1009.86778212 1009.65205923 1010.29397263 1011.78516466 1014.11246284
#  1017.25808964 1021.20040279 1025.91485141 1031.37491212 1037.55286751
#  1044.42037032 1051.94878307 1060.10929404 1068.87280222 1078.20955451
#  1088.08852471 1098.47654862 1109.33726737 1120.6299666  1132.30842296
#  1144.31987864 1156.60426664 1169.09381333 1181.71314936 1194.38005486
#  1207.00693152 1219.5030196  1231.77726791 1243.74163895 1255.31452665
#  1266.42390925 1277.00987506 1287.02624327 1296.44113816 1305.23653367
#  1313.406934   1320.95746397 1327.90169104 1334.25948292 1340.05513195
#  1345.31587353 1350.07082003 1354.35024905 1358.18514078 1361.60685231
#  1364.64683965 1367.33637335 1369.70622953 1371.78636449 1373.60559502
#  1375.19130998 1376.56923381 1377.76325457 1378.79532051 1379.68540173
#  1380.4515088  1381.10975722 1381.67446632 1382.15828136 1382.57230927
#  1382.92626025 1383.22858896 1383.48663111 1383.70673236 1383.89436763
#  1384.05425012 1384.19042951 1384.30637969 1384.40507647 1384.48906594
#  1384.56052431 1384.62131004 1384.67300905 1384.71697383 1384.75435719
#  1384.78614127 1384.81316252 1384.83613304 1384.85565891 1384.87225584
#  1384.88636259 1384.89835232 1384.90854244 1384.91720283 1384.92456295
#  1384.93081792 1384.9361336  1384.94065096 1384.94448986 1384.94775216]
# Best Lambda: 22.23986111323248
# Index of minimum k-fold CV value: 11
